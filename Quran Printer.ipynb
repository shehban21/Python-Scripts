# %%
from selenium import webdriver
import base64

# Set Chrome options
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')

# Initialize the WebDriver
driver = webdriver.Chrome(options=options)

def generate_url(i):
    url = "https://quran411.com/print?s=" + str(i)
    print(url)
    return url

# Open the webpage
for i in range(1,115):
    driver.get(generate_url(i))

# Save page as PDF
    pdf_data = driver.execute_cdp_cmd("Page.printToPDF", {
        "landscape": False,
        "displayHeaderFooter": False,
        "printBackground": True,
        "preferCSSPageSize": True
    })

# Decode base64 PDF data and save to file
    pdf_bytes = base64.b64decode(pdf_data['data'])
    with open("/Users/shehb/Desktop/Quran/" + str(i) + ".pdf", "wb") as f:
        f.write(pdf_bytes)

# Close the browser

    print("PDF saved as output.pdf")
driver.quit()
# Out:
# https://quran411.com/print?s=1
# PDF saved as output.pdf
# https://quran411.com/print?s=2
# PDF saved as output.pdf
# https://quran411.com/print?s=3
# PDF saved as output.pdf
# https://quran411.com/print?s=4
# PDF saved as output.pdf
# https://quran411.com/print?s=5
# PDF saved as output.pdf
# https://quran411.com/print?s=6
# PDF saved as output.pdf
# https://quran411.com/print?s=7
# PDF saved as output.pdf
# https://quran411.com/print?s=8
# PDF saved as output.pdf
# https://quran411.com/print?s=9
# PDF saved as output.pdf
# https://quran411.com/print?s=10
# PDF saved as output.pdf
# https://quran411.com/print?s=11
# PDF saved as output.pdf
# https://quran411.com/print?s=12
# PDF saved as output.pdf
# https://quran411.com/print?s=13
# PDF saved as output.pdf
# https://quran411.com/print?s=14
# PDF saved as output.pdf
# https://quran411.com/print?s=15
# PDF saved as output.pdf
# https://quran411.com/print?s=16
# PDF saved as output.pdf
# https://quran411.com/print?s=17
# PDF saved as output.pdf
# https://quran411.com/print?s=18
# PDF saved as output.pdf
# https://quran411.com/print?s=19
# PDF saved as output.pdf
# https://quran411.com/print?s=20
# PDF saved as output.pdf
# https://quran411.com/print?s=21
# PDF saved as output.pdf
# https://quran411.com/print?s=22
# PDF saved as output.pdf
# https://quran411.com/print?s=23
# PDF saved as output.pdf
# https://quran411.com/print?s=24
# PDF saved as output.pdf
# https://quran411.com/print?s=25
# PDF saved as output.pdf
# https://quran411.com/print?s=26
# PDF saved as output.pdf
# https://quran411.com/print?s=27
# PDF saved as output.pdf
# https://quran411.com/print?s=28
# PDF saved as output.pdf
# https://quran411.com/print?s=29
# PDF saved as output.pdf
# https://quran411.com/print?s=30
# PDF saved as output.pdf
# https://quran411.com/print?s=31
# PDF saved as output.pdf
# https://quran411.com/print?s=32
# PDF saved as output.pdf
# https://quran411.com/print?s=33
# PDF saved as output.pdf
# https://quran411.com/print?s=34
# PDF saved as output.pdf
# https://quran411.com/print?s=35
# PDF saved as output.pdf
# https://quran411.com/print?s=36
# PDF saved as output.pdf
# https://quran411.com/print?s=37
# PDF saved as output.pdf
# https://quran411.com/print?s=38
# PDF saved as output.pdf
# https://quran411.com/print?s=39
# PDF saved as output.pdf
# https://quran411.com/print?s=40
# PDF saved as output.pdf
# https://quran411.com/print?s=41
# PDF saved as output.pdf
# https://quran411.com/print?s=42
# PDF saved as output.pdf
# https://quran411.com/print?s=43
# PDF saved as output.pdf
# https://quran411.com/print?s=44
# PDF saved as output.pdf
# https://quran411.com/print?s=45
# PDF saved as output.pdf
# https://quran411.com/print?s=46
# PDF saved as output.pdf
# https://quran411.com/print?s=47
# PDF saved as output.pdf
# https://quran411.com/print?s=48
# PDF saved as output.pdf
# https://quran411.com/print?s=49
# PDF saved as output.pdf
# https://quran411.com/print?s=50
# PDF saved as output.pdf
# https://quran411.com/print?s=51
# PDF saved as output.pdf
# https://quran411.com/print?s=52
# PDF saved as output.pdf
# https://quran411.com/print?s=53
# PDF saved as output.pdf
# https://quran411.com/print?s=54
# PDF saved as output.pdf
# https://quran411.com/print?s=55
# PDF saved as output.pdf
# https://quran411.com/print?s=56
# PDF saved as output.pdf
# https://quran411.com/print?s=57
# PDF saved as output.pdf
# https://quran411.com/print?s=58
# PDF saved as output.pdf
# https://quran411.com/print?s=59
# PDF saved as output.pdf
# https://quran411.com/print?s=60
# PDF saved as output.pdf
# https://quran411.com/print?s=61
# PDF saved as output.pdf
# https://quran411.com/print?s=62
# PDF saved as output.pdf
# https://quran411.com/print?s=63
# PDF saved as output.pdf
# https://quran411.com/print?s=64
# PDF saved as output.pdf
# https://quran411.com/print?s=65
# PDF saved as output.pdf
# https://quran411.com/print?s=66
# PDF saved as output.pdf
# https://quran411.com/print?s=67
# PDF saved as output.pdf
# https://quran411.com/print?s=68
# PDF saved as output.pdf
# https://quran411.com/print?s=69
# PDF saved as output.pdf
# https://quran411.com/print?s=70
# PDF saved as output.pdf
# https://quran411.com/print?s=71
# PDF saved as output.pdf
# https://quran411.com/print?s=72
# PDF saved as output.pdf
# https://quran411.com/print?s=73
# PDF saved as output.pdf
# https://quran411.com/print?s=74
# PDF saved as output.pdf
# https://quran411.com/print?s=75
# PDF saved as output.pdf
# https://quran411.com/print?s=76
# PDF saved as output.pdf
# https://quran411.com/print?s=77
# PDF saved as output.pdf
# https://quran411.com/print?s=78
# PDF saved as output.pdf
# https://quran411.com/print?s=79
# PDF saved as output.pdf
# https://quran411.com/print?s=80
# PDF saved as output.pdf
# https://quran411.com/print?s=81
# PDF saved as output.pdf
# https://quran411.com/print?s=82
# PDF saved as output.pdf
# https://quran411.com/print?s=83
# PDF saved as output.pdf
# https://quran411.com/print?s=84
# PDF saved as output.pdf
# https://quran411.com/print?s=85
# PDF saved as output.pdf
# https://quran411.com/print?s=86
# PDF saved as output.pdf
# https://quran411.com/print?s=87
# PDF saved as output.pdf
# https://quran411.com/print?s=88
# PDF saved as output.pdf
# https://quran411.com/print?s=89
# PDF saved as output.pdf
# https://quran411.com/print?s=90
# PDF saved as output.pdf
# https://quran411.com/print?s=91
# PDF saved as output.pdf
# https://quran411.com/print?s=92
# PDF saved as output.pdf
# https://quran411.com/print?s=93
# PDF saved as output.pdf
# https://quran411.com/print?s=94
# PDF saved as output.pdf
# https://quran411.com/print?s=95
# PDF saved as output.pdf
# https://quran411.com/print?s=96
# PDF saved as output.pdf
# https://quran411.com/print?s=97
# PDF saved as output.pdf
# https://quran411.com/print?s=98
# PDF saved as output.pdf
# https://quran411.com/print?s=99
# PDF saved as output.pdf
# https://quran411.com/print?s=100
# PDF saved as output.pdf
# https://quran411.com/print?s=101
# PDF saved as output.pdf
# https://quran411.com/print?s=102
# PDF saved as output.pdf
# https://quran411.com/print?s=103
# PDF saved as output.pdf
# https://quran411.com/print?s=104
# PDF saved as output.pdf
# https://quran411.com/print?s=105
# PDF saved as output.pdf
# https://quran411.com/print?s=106
# PDF saved as output.pdf
# https://quran411.com/print?s=107
# PDF saved as output.pdf
# https://quran411.com/print?s=108
# PDF saved as output.pdf
# https://quran411.com/print?s=109
# PDF saved as output.pdf
# https://quran411.com/print?s=110
# PDF saved as output.pdf
# https://quran411.com/print?s=111
# PDF saved as output.pdf
# https://quran411.com/print?s=112
# PDF saved as output.pdf
# https://quran411.com/print?s=113
# PDF saved as output.pdf
# https://quran411.com/print?s=114
# PDF saved as output.pdf
