# %%
from bs4 import BeautifulSoup
import csv
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

def main():
    records = []
    links = []
    driver.get('https://open.spotify.com/playlist/37i9dQZF1DX7iB3RCnBnN4#login')
    time.sleep(2)
    try:
        button = driver.find_element(By.XPATH,'/html/body/div[4]/div/div[3]/div/div[2]/button')
        wait = WebDriverWait(driver, timeout=2)
        wait.until(lambda _ : button.is_displayed())
        if button:
            button.click()
    except Exception:
        pass

    html = driver.find_element(By.TAG_NAME, 'body')
    html.click()
    N = 1
    
    for _ in range(N):
        html.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.5)
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        playlist = soup.find_all('div',{'data-testid':'tracklist-row'})
        for track in playlist:
            link = track.find('a', {'data-testid': 'internal-track-link'})
            print(link.get('href'))
            artist = track.find('span',{'class':'e-9800-text encore-text-body-small encore-internal-color-text-subdued UudGCx16EmBkuFPllvss standalone-ellipsis-one-line'})
#             if link and artist:
#                 if(link.text != ''):
            track_data = { "track" : link.text, "artist" : artist.text}
            records.append(track_data)
#                     records = sorted(set(records)) 
    seen = set()
    unique = []
    
    for track in records:
        identifier = tuple(sorted(track.items()))
        if identifier not in seen:
            seen.add(identifier)
            unique.append(track)
    
    print(len(unique))
    print(unique)
#         for item in tracks:
#             track_name = item.text
#             print(track_name)
#             if(track_name != ''):
#                 records.append(track_name)
#     records = sorted(set(records))
#     print(len(records))
#     print(records)
    driver.close()
    with open("current.csv", 'w', newline='',encoding='utf-8') as f:
        writer = csv.writer(f, dialect='excel')
        for element in records:
            writer.writerow([element])
        f.close()

# %%
main()
# Out:
# /track/3lDSWvR0FXWGXo7mhDUs3v
# /track/6VObnIkLVruX4UVyxWhlqm
# /track/2plbrEY59IikOBgBGLjaoe
# /track/6dOtVTDdiauQNBQEDOtlAB
# /track/6AI3ezQ4o3HUoP6Dhudph3
# /track/0WbMK4wrZ1wFSty9F7FCgu
# /track/7CyPwkp0oE8Ro9Dd5CUDjW
# /track/6WatFBLVB0x077xWeoVc2k
# /track/5XeFesFbtLpXzIVDNQP22n
# /track/3AJwUDP919kvQ9QcozQPxg
# /track/3GCdLUSnKSMJhs4Tj6CV3s
# /track/7KA4W4McWYRpgf0fWsJZWB
# /track/3QaPy1KgI7nu9FJEQUgn6h
# /track/2QjOHCTQ1Jl3zawyYOpxh6
# /track/4wJ5Qq0jBN4ajy7ouZIV1c
# /track/6Qyc6fS4DsZjB2mRW9DsQs
# /track/1JSTJqkT5qHq8MDJnJbRE1
# /track/3w3y8KPTfNeOKPiqUTakBh
# /track/3qhlB30KknSejmIvZZLjOD
# /track/7MXVkk9YMctZqd1Srtv4MB
# /track/1BxfuPKGuaTgP7aM0Bbdwr
# /track/7tI8dRuH2Yc6RuoTjxo4dU
# /track/70LcF31zb1H0PyJoS1Sx1r
# /track/0tgVpDi06FyKpA1z0VMD4v
# /track/75JFxkI2RXiU7L9VXzMkle
# /track/6RUKPb4LETWmmr3iAEQktW
# /track/0KKkJNfGyhkQ5aFogxQAPU
# /track/0VjIjW4GlUZAMYd2vXMi3b
# /track/2qSkIjg1o9h3YT9RAgYN75
# /track/4iZ4pt7kvcaH6Yo8UoZ4s2
# /track/7qiZfU4dY1lWllzX7mPBI3
# /track/7KXjTSCq5nL1LoYtL7XAwS
# /track/4QNpBfC0zvjKqPJcyqBy9W
# /track/0FDzzruyVECATHXKHFs9eJ
# 34
# [{'track': 'Bam Bam (feat. Ed Sheeran)', 'artist': 'Camila Cabello, Ed Sheeran'}, {'track': 'Skyfall', 'artist': 'Adele'}, {'track': 'Die With A Smile', 'artist': 'Lady Gaga, Bruno Mars'}, {'track': 'BIRDS OF A FEATHER', 'artist': 'Billie Eilish'}, {'track': 'Not Like Us', 'artist': 'Kendrick Lamar'}, {'track': 'Good Luck, Babe!', 'artist': 'Chappell Roan'}, {'track': 'One Of The Girls (with JENNIE, Lily Rose Depp)', 'artist': 'The Weeknd, JENNIE, Lily-Rose Depp'}, {'track': 'Si Antes Te Hubiera Conocido', 'artist': 'KAROL G'}, {'track': 'I Wanna Be Yours', 'artist': 'Arctic Monkeys'}, {'track': 'Yellow', 'artist': 'Coldplay'}, {'track': 'All The Stars (with SZA)', 'artist': 'Kendrick Lamar, SZA'}, {'track': 'See You Again (feat. Kali Uchis)', 'artist': 'Tyler, The Creator, Kali Uchis'}, {'track': 'WILDFLOWER', 'artist': 'Billie Eilish'}, {'track': 'Sweater Weather', 'artist': 'The Neighbourhood'}, {'track': 'APT.', 'artist': 'ROSÉ, Bruno Mars'}, {'track': 'Iris', 'artist': 'The Goo Goo Dolls'}, {'track': 'Every Breath You Take', 'artist': 'The Police'}, {'track': 'Locked out of Heaven', 'artist': 'Bruno Mars'}, {'track': 'End of Beginning', 'artist': 'Djo'}, {'track': 'Starboy', 'artist': 'The Weeknd, Daft Punk'}, {'track': 'Cruel Summer', 'artist': 'Taylor Swift'}, {'track': 'Who', 'artist': 'Jimin'}, {'track': 'Creep', 'artist': 'Radiohead'}, {'track': 'Perfect', 'artist': 'Ed Sheeran'}, {'track': 'The Scientist', 'artist': 'Coldplay'}, {'track': 'Something Just Like This', 'artist': 'The Chainsmokers, Coldplay'}, {'track': "That's What I Like", 'artist': 'Bruno Mars'}, {'track': 'Blinding Lights', 'artist': 'The Weeknd'}, {'track': 'Espresso', 'artist': 'Sabrina Carpenter'}, {'track': 'Snooze', 'artist': 'SZA'}, {'track': 'Shape of You', 'artist': 'Ed Sheeran'}, {'track': 'HUMBLE.', 'artist': 'Kendrick Lamar'}, {'track': 'Give Me Everything (feat. Nayer)', 'artist': 'Pitbull, AFROJACK, Ne-Yo, Nayer'}, {'track': 'A Sky Full of Stars', 'artist': 'Coldplay'}]
